# %% [markdown]
# ### Autoreload
#
# Autoreload allows the notebook to dynamically load code: if we update some helper functions *outside* of the notebook, we do not need to reload the notebook.

# %%
# %load_ext autoreload
# %autoreload 2

# %%
# All auxiliary code is in ../src

import sys

sys.path.append("../src/")

# %%
import pandas as pd
import seaborn as sbn
import matplotlib.pyplot as plt
from scipy.stats import entropy

# %% [markdown]
# # Data understanding

# %% [markdown]
# Dataset loading

# %%
races = pd.read_csv('../dataset/races.csv', sep=",")
cyclists = pd.read_csv('../dataset/cyclists.csv', sep=",")

# %%
races.head()
# Out:
#                           _url            name  points  uci_points    length  \
# 0  tour-de-france/1978/stage-6  Tour de France   100.0         NaN  162000.0
# 1  tour-de-france/1978/stage-6  Tour de France   100.0         NaN  162000.0
# 2  tour-de-france/1978/stage-6  Tour de France   100.0         NaN  162000.0
# 3  tour-de-france/1978/stage-6  Tour de France   100.0         NaN  162000.0
# 4  tour-de-france/1978/stage-6  Tour de France   100.0         NaN  162000.0
#
#    climb_total  profile  startlist_quality  average_temperature  \
# 0       1101.0      1.0               1241                  NaN
# 1       1101.0      1.0               1241                  NaN
# 2       1101.0      1.0               1241                  NaN
# 3       1101.0      1.0               1241                  NaN
# 4       1101.0      1.0               1241                  NaN
#
#                   date  position           cyclist  cyclist_age  is_tarmac  \
# 0  1978-07-05 04:02:24         0        sean-kelly         22.0       True
# 1  1978-07-05 04:02:24         1  gerrie-knetemann         27.0       True
# 2  1978-07-05 04:02:24         2    rene-bittinger         24.0       True
# 3  1978-07-05 04:02:24         3    joseph-bruyere         30.0       True
# 4  1978-07-05 04:02:24         4  sven-ake-nilsson         27.0       True
#
#    is_cobbled  is_gravel                          cyclist_team  delta
# 0       False      False  vini-ricordi-pinarello-sidermec-1986    0.0
# 1       False      False                           norway-1987    0.0
# 2       False      False                                   NaN    0.0
# 3       False      False              navigare-blue-storm-1993    0.0
# 4       False      False                            spain-1991    0.0

# %% [markdown]
# As we can see, each data object of the _races_ dataset represents a placement of a cyclist in a particular cycling competition.
# Let's see which column types are automatically inferred by Python.

# %%
races.dtypes
# Out:
# _url                    object
# name                    object
# points                 float64
# uci_points             float64
# length                 float64
# climb_total            float64
# profile                float64
# startlist_quality        int64
# average_temperature    float64
# date                    object
# position                 int64
# cyclist                 object
# cyclist_age            float64
# is_tarmac                 bool
# is_cobbled                bool
# is_gravel                 bool
# cyclist_team            object
# delta                  float64
# dtype: object

# %% [markdown]
# ### Dataframe with only race attributes
# The dataset contains rows with both event-specific information (details related to the cycling event as a whole) and cyclist-specific information (details strictly tied to the performance or attributes of individual cyclists in that event). <br> To produce meaningful statistics, it is beneficial to separate these two types of information. The presence of redundant information can disproportionately weight cycling events with more participants in the overall analysis.
#
# For example, attributes like points are the same for all entries with the same url (indicating the same event). This redundancy leads to a biased distribution for each attribute, favoring events with a higher number of participants.

# %%
#extraction of features related to the race and not to the placement
cyclist_races_columns = ['position', 'cyclist', 'cyclist_age', 'cyclist_team', 'delta', 'date']
races_columns = [col for col in races.columns if col not in cyclist_races_columns]

#races will contain all the 'events' with their specific information
races_data = races.drop_duplicates(subset=races_columns)[races_columns].reset_index(drop=True)

# %% [markdown]
# As mentioned, analyzing data distribution without addressing row redundancy can bias results. The histogram on the right shows the length distribution based on raw data, without grouping by race event, while the histogram on the left is grouped by individual events. This illustrates how the points distribution is distorted by events with many participants, highlighting the impact of redundancy on overall distribution patterns.

# %%
fig, axes = plt.subplots(1, 2, figsize=(12, 5))

# Istogramma per races
sbn.histplot(races['points'], ax=axes[0])
axes[0].set_title(f'Histogram of points in races')
axes[0].set_xlabel('points')
axes[0].set_ylabel('Frequency')

# Istogramma per races_data
sbn.histplot(races_data['points'], ax=axes[1])
axes[1].set_title(f'Histogram of points in races_data')
axes[1].set_xlabel('points')
axes[1].set_ylabel('Frequency')

plt.tight_layout()  # Per evitare sovrapposizioni
plt.show()

# %% [markdown]
# Therefore, to avoid producing misleading distributions and statistics for attributes that are specific to individual races, we chose to split the dataset into two separate tables. This separation minimizes the bias introduced by repeated entries for the same event, ensuring that race-specific attributes are analyzed accurately without distortion from redundancy.

# %% [markdown]
# In this step, we add the date column to races_data because it is specified in the project documentation as the race start date. However, it is important to note that in reality, this date column varies for each placement, meaning it is not actually tied to the race event itself but rather to individual cyclist entries.
# <br>
# Further analyses concerning the relationship between date and delta (a metric for timing differences) will be conducted in the placements notebook.

# %%
# Define columns that belong to the placements (cyclist-specific) and races (event-specific)
cyclist_races_columns = ['position', 'cyclist', 'cyclist_age', 'cyclist_team', 'delta', 'date']
races_columns = [col for col in races.columns if col not in cyclist_races_columns]

# Extract placements_data to contain cyclist-specific information for each event and add 'external key'
placements = races[cyclist_races_columns + ['_url']].reset_index(drop=True)

# Extract races to contain only unique events with event-specific information
races = races.drop_duplicates(subset=races_columns)[races_columns + ['date']].reset_index(drop=True)

# %% [markdown]
# In this dataset, we will focus our analysis on races, which contains unique event-specific information for each race.

# %% [markdown]
# ## Check null for each column

# %% [markdown]
# As we can see below, there are some features with an high percentage of null values, in particular the "average_temperature" feature, which has the 95% of values set to null. A column with a such number of null values provides very few useful information for the analysis. So, keeping such a column could introduce noise and may negatively impact the use of clustering or prediction algorithms.

# %%
nrec = races.shape[0]
results = {
    'Feature': [],
    'Null_counter': [],
    'Perc_of_null_(%)': []
}

for col in races.columns:
    nanCount = races[col].isna().sum()
    perc = round((nanCount*100)/nrec,1)
    results['Feature'].append(col)
    results['Null_counter'].append(nanCount)
    results['Perc_of_null_(%)'].append(perc)

df_results = pd.DataFrame(results)

display(df_results)
# Out:
#                 Feature  Null_counter  Perc_of_null_(%)
# 0                  _url             0               0.0
# 1                  name             0               0.0
# 2                points             4               0.1
# 3            uci_points          3682              69.7
# 4                length             0               0.0
# 5           climb_total          2214              41.9
# 6               profile          2408              45.6
# 7     startlist_quality             0               0.0
# 8   average_temperature          5076              96.1
# 9             is_tarmac             0               0.0
# 10           is_cobbled             0               0.0
# 11            is_gravel             0               0.0
# 12                 date             0               0.0

# %% [markdown]
# ## Check distribution of null values across rows

# %%
# compute the number of null values for each row
races['null_count'] = races.isnull().sum(axis=1)

plt.figure(figsize=(10, 6))
#ax=sbn.displot(races['null_count'], bins="sturges")
ax=sbn.countplot(x='null_count', data=races, legend=False)
total = len(races['null_count'])

#% over the bars
for p in ax.patches:
    height = p.get_height()  #height of the bar
    percentage = 100 * height / total  #determine the %
    ax.text(
        p.get_x() + p.get_width() / 2,  #Position the text in the middle of the bar
        height,  #Position on the bar end
        f'{percentage:.2f}%',  # Mostriamo la percentuale con 1 decimale
        ha='center',           # Horizontal alignment
        va='bottom'            # Vertical alignment
    )

plt.title('Distribution of null values per row')
plt.xlabel('Number of null column values per row')
plt.ylabel('Number of rows')

plt.show()
plt.close()

# %% [markdown]
# We show the rows with the highest number of null values

# %%
max_null_count = races['null_count'].max()
rows_with_max_null = races[races['null_count'] == max_null_count]
print("Rows with the highest number of null values:")
display(rows_with_max_null)
races.drop(columns=['null_count'], inplace=True)
# Out:
# Rows with the highest number of null values:
#                                  _url                          name  points  \
# 3     volta-a-catalunya/1999/prologue    Volta Ciclista a Catalunya    50.0
# 8     volta-a-catalunya/1981/stage-2b    Volta Ciclista a Catalunya    50.0
# 9            paris-nice/1994/stage-8b                  Paris - Nice    50.0
# 10     tirreno-adriatico/1984/stage-1             Tirreno-Adriatico    50.0
# 11              dauphine/1991/stage-2  Critérium du Dauphiné Libéré    50.0
# ...                               ...                           ...     ...
# 5262    tour-de-romandie/2002/stage-2              Tour de Romandie    50.0
# 5265          paris-nice/1990/stage-5                  Paris - Nice    50.0
# 5267          paris-nice/2000/stage-3                  Paris - Nice    50.0
# 5273   tirreno-adriatico/1993/stage-3             Tirreno-Adriatico    50.0
# 5278          paris-nice/1976/stage-2                  Paris - Nice    50.0
#
#       uci_points    length  climb_total  profile  startlist_quality  \
# 3            NaN    8100.0          NaN      NaN                804
# 8            NaN   30000.0          NaN      NaN                388
# 9            NaN   12500.0          NaN      NaN                900
# 10           NaN  189000.0          NaN      NaN                541
# 11           NaN  222000.0          NaN      NaN                830
# ...          ...       ...          ...      ...                ...
# 5262         NaN  172800.0          NaN      NaN                535
# 5265         NaN  164000.0          NaN      NaN                995
# 5267         NaN  178000.0          NaN      NaN                880
# 5273         NaN  184000.0          NaN      NaN                568
# 5278         NaN  185000.0          NaN      NaN                779
#
#       average_temperature  is_tarmac  is_cobbled  is_gravel  \
# 3                     NaN       True       False      False
# 8                     NaN       True       False      False
# 9                     NaN       True       False      False
# 10                    NaN       True       False      False
# 11                    NaN       True       False      False
# ...                   ...        ...         ...        ...
# 5262                  NaN       True       False      False
# 5265                  NaN       True       False      False
# 5267                  NaN       True       False      False
# 5273                  NaN       True       False      False
# 5278                  NaN       True       False      False
#
#                      date  null_count
# 3     1999-06-17 00:10:12           4
# 8     1981-09-05 00:44:24           4
# 9     1994-03-13 00:22:06           4
# 10    1984-03-09 05:14:53           4
# 11    1991-06-05 05:41:27           4
# ...                   ...         ...
# 5262  2002-05-02 03:45:11           4
# 5265  1990-03-09 04:03:24           4
# 5267  2000-03-08 04:28:35           4
# 5273  1993-03-12 05:14:05           4
# 5278  1976-03-09 04:58:28           4
#
# [1916 rows x 14 columns]

# %% [markdown]
# # Data distribution

# %% [markdown]
# Custom procedure that produces some basic statistics on a single feature of the dataset.

# %%
from distribution_utility import stats_and_distribution, show_stats, calculate_outlier_bounds
from cast_utility import cast_column_to_Int64, cast_column_to_string

# %% [markdown]
# ## Features casting
# ### - float64 -> Int64 (which allows to correctly manage also Nan values)
# ### - object -> string (from pandas 1.0)
# ### - bool -> Int64
#
# Before doing the casting from float64 to Int64, we make sure that the result is equal to the previous value

# %% [markdown]
# ## _url

# %% [markdown]
# The _\_url_ is a categorical feature of type object. We can convert it into pandas string

# %%
cast_column_to_string(races, '_url')
# Out:
# Column casted from object to string

# %%
show_stats(races, "_url", attr_type='categorical')
# Out:
# Description of attribute '_url':
# count                            5281
# unique                           5281
# top       tour-de-france/1978/stage-6
# freq                                1
# Name: _url, dtype: object
# Unique values:
# ['tour-de-france/1978/stage-6' 'vuelta-a-espana/2016/stage-14'
#  'tour-de-france/2019/stage-21' ... 'paris-nice/1976/stage-2'
#  'volta-a-catalunya/2016/stage-7' 'giro-d-italia/2010/stage-1']
#
# Null values: 0 over 5281 records - (0.00%)
#
# Top 5 common value:
# _url
# tour-de-france/1978/stage-6      1
# vuelta-a-espana/1990/stage-19    1
# paris-nice/1972/stage-2          1
# tour-de-romandie/2021/stage-4    1
# tour-de-france/1986/prologue     1
# Name: count, dtype: int64

# %% [markdown]
# The __url_ feature can be considered as an identifier of the race event. The url is in the form _eventName/year/stagename_.<br>
# The fact that there are many rows with URLs starting with _Tour de France_ or _Giro d'Italia_ is related to the importance of these two events in the cycling world. These two races typically have a lot of participants and are composed of more than one stage. <br>
# We initially found the bar plot to be illegible due to the high number of unique values in the URLs. To address this, we used the initial part of the URLs to identify the event_name associated with each event. This truncation reduced complexity and significantly enhanced the clarity of our visualization. By doing so, we created a more interpretable bar plot of the distribution of events by event_name, making the data both informative and accessible.

# %%
event_names = races['_url'].apply(lambda x: x.split('/')[0])
events_counts = event_names.value_counts()

plt.figure(figsize=(12,8))
sbn.barplot(x= events_counts.index, y= events_counts.values)
plt.title('URL Distribution by event_name')
plt.xlabel('event_name')
plt.ylabel('Count')
plt.xticks(rotation=45, ha='right')  # Rotate labels and align them horizontally
plt.tight_layout()  # Adjust layout to ensure everything fits without overlapping
plt.show()

# %% [markdown]
# ## name

# %% [markdown]
# Convert it from object to pandas string

# %%
cast_column_to_string(races, 'name')
# Out:
# Column casted from object to string

# %%
stats_and_distribution(races, 'name', attr_type='categorical')
# Out:
# Description of attribute 'name':
# count               5281
# unique                61
# top       Tour de France
# freq                 911
# Name: name, dtype: object
# Unique values:
# ['Tour de France' 'Vuelta a España' 'Volta Ciclista a Catalunya'
#  'Paris - Nice' 'Tirreno-Adriatico' 'Critérium du Dauphiné Libéré'
#  'Critérium du Dauphiné' 'Ronde van Vlaanderen / Tour des Flandres'
#  'Milano-Sanremo' 'Tour de Suisse' "Giro d'Italia" 'Gran Camiño'
#  'Tour de Romandie' 'Volta a Catalunya' 'La Vuelta ciclista a España'
#  'La Flèche Wallonne' 'E3-Prijs Harelbeke' 'Vuelta al País Vasco'
#  'Vuelta Ciclista al País Vasco' 'Liège - Bastogne - Liège'
#  'Paris-Roubaix' 'UAE Tour' 'World Championships ME - Road Race'
#  'Amstel Gold Race' 'Dwars door België / À travers la Belgique'
#  'Itzulia Basque Country' 'World Championships - Road Race'
#  'Criterium du Dauphiné Libére' 'Omloop Het Volk'
#  'Clasica Ciclista San Sebastian' 'Paris - Roubaix' 'Strade Bianche'
#  'Giro di Lombardia' 'Criterium du Dauphiné' 'O Gran Camiño'
#  'Grand Prix Cycliste de Quebec' 'Grand Prix Cycliste de Montréal'
#  'Ronde van Vlaanderen - Tour des Flandres ME'
#  'Dwars door Vlaanderen - A travers la Flandre ME'
#  'Clásica Ciclista San Sebastián' 'Donostia San Sebastian Klasikoa'
#  'Dwars door Vlaanderen' 'Omloop Het Nieuwsblad ME' 'Il Lombardia'
#  'E3 Harelbeke' 'Ronde van Vlaanderen / Tour des Flandres ME'
#  'E3 Prijs Vlaanderen' 'E3 Saxo Bank Classic' 'Monte Paschi Eroica'
#  'Grand Prix Cycliste de Québec' 'E3 Prijs Vlaanderen - Harelbeke'
#  'Liège-Bastogne-Liège' 'Clásica San Sebastián'
#  'Montepaschi Strade Bianche - Eroica Toscana'
#  'Dwars door Vlaanderen / A travers la Flandre' 'Record Bank E3 Harelbeke'
#  'Omloop Het Volk ME' 'E3 BinckBank Classic'
#  'Dwars door Vlaanderen / A travers la Flandre ME' 'E3 Saxo Classic'
#  'Clásica Ciclista San Sebastian']
#
# Null values: 0 over 5281 records - (0.00%)
#
# Top 5 common value:
# name
# Tour de France     911
# Vuelta a España    794
# Giro d'Italia      714
# Tour de Suisse     503
# Paris - Nice       394
# Name: count, dtype: int64

# %% [markdown]
# There are no missing values and, as expected and already explained, the most common values are the names of the more prestigious races. <br>
# We encountered a high number of unique values in the 'name' attribute compared to the truncated _url attribute. This can be attributed to the presence of articles or additional letters, causing variations even for the same event.

# %% [markdown]
# ## points

# %% [markdown]
# _Points_ and _uci points_ are numeric continuous attributes. Their type can be cast to int since there are no decimals.

# %%
cast_column_to_Int64(races, 'points')
# Out:
# Column casted from float64 to Int64

# %%
stats_and_distribution(races, "points", attr_type='numerical')
# Out:
# Description of attribute 'points':
# count       5277.0
# mean     89.465795
# std      61.414859
# min           18.0
# 25%           50.0
# 50%           80.0
# 75%          100.0
# max          350.0
# Name: points, dtype: Float64
# Unique values:
# <IntegerArray>
# [100, 80, 50, 275, 20, 225, 125, 350, 75, 70, 30, 150, 35, <NA>, 18]
# Length: 15, dtype: Int64
#
# Null values: 4 over 5281 records - (0.08%)
#
# Top 5 common value:
# points
# 50     2098
# 80     1596
# 100     886
# 275     256
# 225     201
# Name: count, dtype: Int64
# Outliers in points: [np.int64(225), np.int64(275), np.int64(350)]

# %% [markdown]
# The histogram and the boxplot of points shows a distribution primarily between 50 and 100, with outliers extending up to around 350. <br>
# Many races have scores in this range, and those beyond the 95th quantile are notably longer. In fact, all these races have lengths above the 85th percentile of the overall lengths.

# %%
quantile_95_points = races['points'].quantile(0.95)
quantile_85_length = races['length'].quantile(0.85)
races[races['points'] > quantile_95_points]['length'].min() > quantile_85_length
# Out:
# np.True_

# %% [markdown]
# The relationship we noted between points and length doesn't hold when it comes to climb_total. Specifically, the minimum climb_total for races with points above the 95th quantile does not exceed the 85th percentile of climb_total values. This discrepancy indicates that while longer races tend to have higher points, the same cannot be inferred for climb_total.

# %%
quantile_95_points = races['points'].quantile(0.95)
quantile_85_climb_total = races['climb_total'].quantile(0.85)
races[races['points'] > quantile_95_points]['climb_total'].min() > quantile_85_climb_total
# Out:
# np.False_

# %% [markdown]
# Moreover, all high-scoring races are of the 'result' type. We found that there are no races with high points that are not classified as 'result'.

# %%
quantile_95_points = races['points'].quantile(0.95)
races[(races['points'] > quantile_95_points) & ~races['_url'].str.contains('result')].size == 0
# Out:
# True

# %% [markdown]
# ## uci_points

# %%
cast_column_to_Int64(races, 'uci_points')
# Out:
# Column casted from float64 to Int64

# %%
stats_and_distribution(races, "uci_points", attr_type='numerical')
# Out:
# Description of attribute 'uci_points':
# count        1599.0
# mean      82.097561
# std      113.896141
# min             6.0
# 25%            16.0
# 50%            60.0
# 75%           100.0
# max           800.0
# Name: uci_points, dtype: Float64
# Unique values:
# <IntegerArray>
# [<NA>,  100,  120,   50,   60,    6,   14,   16,  500,   20,   40,  210,  400,
#   300,  800,  180,  200,  600,   80,   10,  402]
# Length: 21, dtype: Int64
#
# Null values: 3682 over 5281 records - (69.72%)
#
# Top 5 common value:
# uci_points
# 100    288
# 6      285
# 60     271
# 16     229
# 120    123
# Name: count, dtype: Int64
# Outliers in uci_points: [np.int64(800), np.int64(300), np.int64(400), np.int64(402), np.int64(500), np.int64(600)]

# %% [markdown]
# ## length

# %% [markdown]
# The _length_ is a numeric continuous attribute representing the length of the race event. The values in the column may have some decimal places. Since the feature represents the length of the race in meters, and there are decimals in irrelevant positions (e.g. 32200.000000000003638), we decide to round to the unit (meters), so we cast to int.

# %%
# We use 'Int64' to correctly manage also NaN values
import numpy as np


print(races['length'].dtype)

pd.set_option('display.float_format', '{:.15f}'.format)
decimal_values = races['length'] % 1 != 0
values_with_decimals = races['length'][decimal_values]

print(f"\nSome of the values with several decimals places:\n{values_with_decimals}\n")

rounded_length = races['length'].round(1)
rounded_length_int = rounded_length.astype('Int64')
# print(rounded_length_int)
try:
    res = np.all(rounded_length_int == races['length'].round(1))
    print("Castable")
    if res:
        races['length'] = races['length'].round().astype('Int64')
        print(races['length'].dtype)
        decimal_values = races['length'] % 1 != 0
        values_with_decimals = races['length'][decimal_values]
        print(values_with_decimals)

        pd.reset_option('display.float_format')
except TypeError:
    print("Not castable!")
# Out:
# float64
#
# Some of the values with several decimals places:
# 103     32200.000000000003638
# 224    258600.000000000029104
# 542    256600.000000000029104
# 1451    16190.000000000001819
# 1568   259100.000000000029104
# 1621   257399.999999999970896
# 1853     4019.999999999999091
# 1941   257600.000000000029104
# 2047   259100.000000000029104
# 2091   261600.000000000029104
# 2440   260399.999999999970896
# 2780    32200.000000000003638
# 3314   261399.999999999970896
# 4390   259350.000000000029104
# 4587   258100.000000000029104
# Name: length, dtype: float64
#
# Castable
# Int64
# Series([], Name: length, dtype: Int64)

# %%
stats_and_distribution(races, "length", attr_type='numerical')
# Out:
# Description of attribute 'length':
# count           5281.0
# mean     165685.627722
# std       67889.860679
# min             1000.0
# 25%           149000.0
# 50%           179000.0
# 75%           205500.0
# max           338000.0
# Name: length, dtype: Float64
# Unique values:
# <IntegerArray>
# [162000, 196000, 128000,   8100, 192900, 117500,  52000, 154800,  30000,
#   12500,
#  ...
#   98800,  97500, 205300, 142700,  82600, 320500, 224500, 301000, 184200,
#  136400]
# Length: 1280, dtype: Int64
#
# Null values: 0 over 5281 records - (0.00%)
#
# Top 5 common value:
# length
# 200000    46
# 190000    42
# 175000    41
# 202000    40
# 180000    39
# Name: count, dtype: Int64
# Outliers in length: [np.int64(4100), np.int64(59400), np.int64(8200), np.int64(12300), np.int64(63500), np.int64(16400), np.int64(20500), np.int64(24600), np.int64(36900), np.int64(41000), np.int64(297000), np.int64(53300), np.int64(6200), np.int64(61500), np.int64(14400), np.int64(18500), np.int64(26700), np.int64(30800), np.int64(338000), np.int64(34900), np.int64(39000), np.int64(4200), np.int64(6250), np.int64(59500), np.int64(12400), np.int64(16500), np.int64(20600), np.int64(24700), np.int64(37000), np.int64(293000), np.int64(6300), np.int64(57500), np.int64(10400), np.int64(14500), np.int64(18600), np.int64(26800), np.int64(30900), np.int64(35000), np.int64(291000), np.int64(55500), np.int64(4300), np.int64(8400), np.int64(12500), np.int64(33000), np.int64(37100), np.int64(41200), np.int64(53500), np.int64(6400), np.int64(22800), np.int64(26900), np.int64(31000), np.int64(8500), np.int64(12600), np.int64(18750), np.int64(49500), np.int64(6500), np.int64(18800), np.int64(27000), np.int64(31100), np.int64(47500), np.int64(4500), np.int64(8600), np.int64(12700), np.int64(16800), np.int64(25000), np.int64(29100), np.int64(45500), np.int64(6600), np.int64(16850), np.int64(18900), np.int64(39400), np.int64(2550), np.int64(4600), np.int64(8700), np.int64(64000), np.int64(12800), np.int64(25100), np.int64(41500), np.int64(6700), np.int64(10800), np.int64(62000), np.int64(19000), np.int64(27200), np.int64(39500), np.int64(4700), np.int64(8800), np.int64(60000), np.int64(12900), np.int64(17000), np.int64(25200), np.int64(29300), np.int64(33400), np.int64(37500), np.int64(41600), np.int64(45700), np.int64(6800), np.int64(58000), np.int64(10900), np.int64(15000), np.int64(23200), np.int64(6820), np.int64(4800), np.int64(8900), np.int64(13000), np.int64(17100), np.int64(33500), np.int64(54000), np.int64(4850), np.int64(6900), np.int64(11000), np.int64(15100), np.int64(19200), np.int64(15110), np.int64(31500), np.int64(43800), np.int64(52000), np.int64(4900), np.int64(9000), np.int64(13100), np.int64(29500), np.int64(50000), np.int64(2900), np.int64(7000), np.int64(15200), np.int64(23400), np.int64(25450), np.int64(27500), np.int64(35700), np.int64(39800), np.int64(48000), np.int64(5000), np.int64(9100), np.int64(60300), np.int64(13200), np.int64(17300), np.int64(25500), np.int64(29600), np.int64(33700), np.int64(37800), np.int64(46000), np.int64(3000), np.int64(7100), np.int64(11200), np.int64(15300), np.int64(19400), np.int64(23500), np.int64(44000), np.int64(1000), np.int64(5100), np.int64(9200), np.int64(13300), np.int64(320500), np.int64(17400), np.int64(21500), np.int64(25600), np.int64(5120), np.int64(33800), np.int64(37900), np.int64(42000), np.int64(298000), np.int64(3100), np.int64(7200), np.int64(11300), np.int64(19500), np.int64(27700), np.int64(31800), np.int64(40000), np.int64(5200), np.int64(9300), np.int64(13400), np.int64(299000), np.int64(21600), np.int64(25700), np.int64(29800), np.int64(38000), np.int64(294000), np.int64(1150), np.int64(3200), np.int64(7300), np.int64(58500), np.int64(15500), np.int64(19600), np.int64(27800), np.int64(31900), np.int64(36000), np.int64(292000), np.int64(40100), np.int64(44200), np.int64(5300), np.int64(56500), np.int64(9400), np.int64(60600), np.int64(13500), np.int64(17600), np.int64(21700), np.int64(34000), np.int64(42200), np.int64(3300), np.int64(11500), np.int64(32000), np.int64(40200), np.int64(44300), np.int64(3340), np.int64(52500), np.int64(5400), np.int64(7450), np.int64(9500), np.int64(21800), np.int64(25900), np.int64(30000), np.int64(34100), np.int64(46400), np.int64(3400), np.int64(7500), np.int64(15700), np.int64(7510), np.int64(23900), np.int64(28000), np.int64(32100), np.int64(36200), np.int64(5500), np.int64(9600), np.int64(26000), np.int64(34200), np.int64(42400), np.int64(46500), np.int64(3500), np.int64(7600), np.int64(15800), np.int64(19900), np.int64(24000), np.int64(5570), np.int64(32200), np.int64(5600), np.int64(15840), np.int64(9700), np.int64(13800), np. ...

# %% [markdown]
# We identified that many of the very short races, particularly those considered outliers, are prologues. This trend highlights how prologues tend to be significantly shorter compared to other race stages, providing a distinct category within our dataset.

# %%
lower_bound = calculate_outlier_bounds(races, 'length')['lower']
races[races['length'] < lower_bound]['_url'].str.split('/').str[2].value_counts().head()
# Out:
# _url
# prologue    181
# stage-1      51
# stage-5      35
# stage-8      31
# stage-4      31
# Name: count, dtype: int64

# %% [markdown]
# Furthermore, while there are some long races not classified as 'result,' a significant number of these long races are indeed of the 'result' type. This underscores the trend that many single-stage races tend to be longer in length.

# %%
upper_bound = calculate_outlier_bounds(races, 'length')['upper']
races[races['length'] > upper_bound]['_url'].str.split('/').str[2].value_counts().head()
# Out:
# _url
# result      39
# stage-4      2
# stage-20     1
# stage-9      1
# stage-21     1
# Name: count, dtype: int64

# %% [markdown]
# ## climb_total

# %% [markdown]
# _Climb total_ is a numeric continuous attribute representing the number of metres climbed during the race event. Its type can be cast to int since there are no decimals.

# %%
cast_column_to_Int64(races, 'climb_total')
# Out:
# Column casted from float64 to Int64

# %%
stats_and_distribution(races, "climb_total", attr_type='numerical')
# Out:
# Description of attribute 'climb_total':
# count         3067.0
# mean     2375.650473
# std      1394.390513
# min              2.0
# 25%           1333.0
# 50%           2307.0
# 75%           3358.0
# max           6974.0
# Name: climb_total, dtype: Float64
# Unique values:
# <IntegerArray>
# [1101, 5575,  781, <NA>, 3743, 3817, 1351, 2008, 3828, 3867,
#  ...
#  2190, 1410,  477, 3765, 3562, 4156, 2359,  713, 1441,   60]
# Length: 2118, dtype: Int64
#
# Null values: 2214 over 5281 records - (41.92%)
#
# Top 5 common value:
# climb_total
# 2500    36
# 3500    36
# 4000    29
# 3000    24
# 4500    21
# Name: count, dtype: Int64
# Outliers in climb_total: [np.int64(6500), np.int64(6425), np.int64(6939), np.int64(6589), np.int64(6974), np.int64(6687)]

# %% [markdown]
# The histogram of climb_total shows a positive skew, indicating most races have fewer climbing kilometers, while a few have significantly more. The boxplot reveals that the median climb_total is around 3000 meters, with some outliers exceeding 6000 meters. These outliers represent exceptionally challenging races.

# %% [markdown]
# ## profile

# %% [markdown]
# The _profile_ feature is a categorical ordinal attribute. It has a range from 1.0 to 5.0 and it represents the difficulty of that race event. Its type can be cast to int since there are no decimals. <br>

# %%
cast_column_to_Int64(races, 'profile')
# Out:
# Column casted from float64 to Int64

# %%
stats_and_distribution(races, "profile", attr_type='categorical')
# Out:
# Description of attribute 'profile':
# count     2873
# unique       5
# top          2
# freq       867
# Name: profile, dtype: int64
# Unique values:
# [1 5 <NA> 3 2 4]
#
# Null values: 2408 over 5281 records - (45.60%)
#
# Top 5 common value:
# profile
# 2    867
# 1    817
# 5    575
# 3    327
# 4    287
# Name: count, dtype: int64

# %% [markdown]
# ## startlist_quality

# %% [markdown]
# The _startlist quality_ feature is a numeric continuous attribute. It's a number that summarizes the overall competitiviness of the cyclists participating to a race event. It is already of type int

# %%
print(races['startlist_quality'].dtype)
races['startlist_quality'].value_counts()
# Out:
# int64
# startlist_quality
# 971     60
# 838     50
# 1872    45
# 1812    45
# 920     43
#         ..
# 1594     1
# 304      1
# 1120     1
# 594      1
# 1149     1
# Name: count, Length: 697, dtype: int64

# %%
stats_and_distribution(races, "startlist_quality", attr_type='numerical')
# Out:
# Description of attribute 'startlist_quality':
# count    5281.000000
# mean      988.701572
# std       380.450977
# min       115.000000
# 25%       747.000000
# 50%       917.000000
# 75%      1165.000000
# max      2047.000000
# Name: startlist_quality, dtype: float64
# Unique values:
# [1241  821 1699  804 1551  899  659  388  900  541  830  789  602  817
#  1400 1161 1040  896  791  819  670  225  520 1057  809  828  722  747
#   714  815  376  621  760  798  933 1994 1437 1362  884 1150  971  881
#  1112 1175  891  878  400  936  692  727 1002  928 1196 1489  687  585
#   835  673 1328  885  502  861  982  923 1036 1690  925  989 1109 1084
#   803  792  548  668 1713 1520 1959  883  859 2047 1024  533 1269  751
#  1202  570 1703 1416  251 1158 1139  657 1048  521 1034 1099  880 1029
#   627  340  767  737 1220  824  369 1255 1019  995 1059 1342  968  676
#  1381  705  680  779 1123 1020 1632 1251 1470  708  892  523  590  604
#   781  614 1309  951 1812  877 1758  843 1041 1646  935  660  961 1238
#  1496  765  494 1933  956 1849 1136  393  882  597  874  908  888  530
#  1089  446  838  373 1872  638  794  932 1331  377  719 1121 1042 1165
#  1105 1535 1492  732  866  920  917 1584  653  906  551  611  772  852
#   607 1177  389  873  966  775  790 1090  302  478  952 1176 1017 1278
#   762  508 1612  930  477 1557  972  811 1941 1365 1555  442 1443  655
#   807 1044  463  200 1685  721  960 1182 1005  698 1067  352 1061  850
#   997  538  844  636  869  699  929 1170  616  490 1063  944  800 1871
#   988  778 1292 1079 1038  480 1791  889  156  857  536  710  605 1058
#   724  439  608  771 1086  766  549  327  516  806 1033  886  734 1148
#   981  764 1053  691  457  666  758  658 1146  741 1117  975  518 1804
#  1023  847 1164 1224 1045  431 1108  362 1101  973  579  927  774  895
#   491 1128  926  795 1689 1434 1275  915  914  492  690  943  731  507
#  1188  700  574  603  802  568  816  709  922 1197  433  343  785  572
#   386  429 1212 1630  855  780  782  898  890 1192  940  701  985  438
#  1216  391  831  637  697  505  447 1100 1110  787  319  529 1091 1168
#  1704 1688  394  644  958  544  526  864 1225 1530  970  565  566  704
#   681  379 1026  473  651  599  455  953  902 1198  556 1243 1210  949
#   941  912  601  910 1092  171  746  512  646 1047  540  269 1377  717
#  1731  754  909  560 1133  674 1242  845  872  557  640  749 1071  615
#   428 1485 1189  323 1008  837  992  641  535 1230  740  938  688  678
#  1115  643 1085  755  633 1232  998  595  796  868  823 1476  426 1166
#   443  649  853  261 1677  684  427 1088 1147  515 1352  583 1082 1070
#  1206  742  441  419  748  763  341  808  451 1012  372  250  867  460
#  1068  194 1359  594 1087 1458  559 1120  304 1594  588  733 1122  652
#   532  918  947  489 1526  783  735 1201  479  586  769  959  546 1603
#   829  513 1056  693 1163  634  854  799  832  454  335 1254  328  434
#  1608 1247  228 1080  262  339 1235  484  504  695 1259  978 1233 1249
#  1229  842  682  416  281  625  630  584 1140 1486 1290  282  303 1253
#   424 1208  539 1217 1294  578 1134  399 1585 1054 1404  777 1159  996
#   471  410 1386 1143  977  756 1178  836  860 1096  865  685  330  554
#   617  575  648 1263 1116 1398  862  216 1307 1614 1305  718  234  136
#  1428 1039  759  498 1480 1154 1353  623  488 1186  320  527  558  403
#   483  445  683  226  563  645  707  631  893 1313 1106 1626 1030 1277
#  1436  962 1374 1138 1094  580  887  589 1256 1303  449 1211  561 1018
#  1052  241  472 1179  770  232  191  661  964  542 1319 1191 1327  474
#   552 1723  115 1355 1346 1306 1098  656 1130  378 1329 1347  467 1218
#  1025 1296 1357  418  510  632 1009  258 1600  141  752 1580 1028 1013
#   493 1032  993 1566  423 1439 1069 1599  301  567 1016  856  358  430
#   610  773  662  613  827 1152 1332 1310  797 1004  999  318  677 1075
#  1322  805  626 1794 1483  736  390  745 1601 1171 1149]
#
# Null values: 0 over 5281 records - (0.00%)
#
# Top 5 common value:
# startlist_quality
# 971     60
# 838     50
# 1872    45
# 1812    45
# 920     43
# Name: count, dtype: int64
# Outliers in startlist_quality: [np.int64(1794), np.int64(1959), np.int64(1994), np.int64(1804), np.int64(1933), np.int64(1871), np.int64(1872), np.int64(115), np.int64(1812), np.int64(1941), np.int64(1849), np.int64(2047)]

# %% [markdown]
# The analysis of the distribution of startlist quality in cycling races shows a pronounced positive skew: most events have medium to low competitiveness, while a select few prestigious races attract the top athletes, creating a right tail in the distribution. The analysis confirms that only a narrow elite of races can draw the strongest champions in the cycling world, highlighting a clear distinction between high-prestige events and the rest of the calendar.

# %% [markdown]
# ## average_temperature
# The _average temperature_ feature is a numeric continous attribute. It describes the average temperature recorded during that race. Its type can be cast to int since there are no decimals.

# %%
# We use 'Int64' to correctly manage also NaN values
cast_column_to_Int64(races, 'average_temperature')
# Out:
# Column casted from float64 to Int64

# %%
stats_and_distribution(races, "average_temperature", attr_type='numerical')
# Out:
# Description of attribute 'average_temperature':
# count       205.0
# mean     21.62439
# std      5.959042
# min          10.0
# 25%          17.0
# 50%          22.0
# 75%          26.0
# max          36.0
# Name: average_temperature, dtype: Float64
# Unique values:
# <IntegerArray>
# [<NA>,   24,   22,   13,   10,   19,   29,   20,   11,   25,   15,   23,   31,
#    21,   27,   32,   16,   14,   26,   30,   28,   18,   17,   34,   12,   35,
#    36,   33]
# Length: 28, dtype: Int64
#
# Null values: 5076 over 5281 records - (96.12%)
#
# Top 5 common value:
# average_temperature
# 23    15
# 20    14
# 22    14
# 24    12
# 25    12
# Name: count, dtype: Int64
# Outliers in average_temperature: []

# %% [markdown]
# ## is_tarmac
# We convert it from bool to int

# %%
stats_and_distribution(races, 'is_tarmac', attr_type='binary')
# Out:
# Description of attribute 'is_tarmac':
# count     5281
# unique       2
# top       True
# freq      4645
# Name: is_tarmac, dtype: object
# Unique values:
# [ True False]
#
# Null values: 0 over 5281 records - (0.00%)
#
# Top 5 common value:
# is_tarmac
# True     4645
# False     636
# Name: count, dtype: int64

# %%
print(races['is_tarmac'].dtype)
races['is_tarmac'] = races['is_tarmac'].astype('Int64')
print(races['is_tarmac'].dtype)
# Out:
# bool
# Int64

# %% [markdown]
# ## is_cobbled
# This feature has only False values, so it doesn't provide any information to the analysis. For the moment, we convert it from bool to int.

# %%
stats_and_distribution(races, 'is_cobbled', attr_type='binary')
# Out:
# Description of attribute 'is_cobbled':
# count      5281
# unique        1
# top       False
# freq       5281
# Name: is_cobbled, dtype: object
# Unique values:
# [False]
#
# Null values: 0 over 5281 records - (0.00%)
#
# Top 5 common value:
# is_cobbled
# False    5281
# Name: count, dtype: int64

# %%
print(races['is_cobbled'].dtype)
races['is_cobbled'] = races['is_cobbled'].astype('Int64')
print(races['is_cobbled'].dtype)
# Out:
# bool
# Int64

# %% [markdown]
# ## is_gravel
# This feature has only False values, so it doesn't provide any information to the analysis. For the moment, we convert it from bool to int.

# %%
stats_and_distribution(races, 'is_gravel', attr_type='binary')
# Out:
# Description of attribute 'is_gravel':
# count      5281
# unique        1
# top       False
# freq       5281
# Name: is_gravel, dtype: object
# Unique values:
# [False]
#
# Null values: 0 over 5281 records - (0.00%)
#
# Top 5 common value:
# is_gravel
# False    5281
# Name: count, dtype: int64

# %%
print(races['is_gravel'].dtype)
races['is_gravel'] = races['is_gravel'].astype('Int64')
print(races['is_gravel'].dtype)
# Out:
# bool
# Int64

# %% [markdown]
# ## date
# We convert date into datetime format, but since we are not interested in time information, we set it to midnight.
#
# The _date_ feature is numeric continuos attribute. It represents the timestamp of the race start. For our purposes the time is irrelevant, so the column can be cast to 'date'. <br>

# %%
races['date'] = pd.to_datetime(races['date']).dt.floor('d')
print(races['date'].dtype)
# Out:
# datetime64[ns]

# %%
show_stats(races, 'date')
# Out:
# Description of attribute 'date':
# count                             5281
# mean     2001-05-16 02:29:41.935239424
# min                1970-02-28 00:00:00
# 25%                1990-10-20 00:00:00
# 50%                2002-03-18 00:00:00
# 75%                2013-03-10 00:00:00
# max                2023-07-29 00:00:00
# Name: date, dtype: object
# Unique values:
# <DatetimeArray>
# ['1978-07-05 00:00:00', '2016-09-03 00:00:00', '2019-07-28 00:00:00',
#  '1999-06-17 00:00:00', '2022-07-10 00:00:00', '2017-09-09 00:00:00',
#  '1978-07-14 00:00:00', '2018-03-25 00:00:00', '1981-09-05 00:00:00',
#  '1994-03-13 00:00:00',
#  ...
#  '2017-07-29 00:00:00', '2014-05-20 00:00:00', '1982-07-25 00:00:00',
#  '2016-07-24 00:00:00', '2010-07-11 00:00:00', '2017-05-07 00:00:00',
#  '2000-04-10 00:00:00', '1976-03-09 00:00:00', '2016-03-27 00:00:00',
#  '2010-05-08 00:00:00']
# Length: 4708, dtype: datetime64[ns]
#
# Null values: 0 over 5281 records - (0.00%)
#
# Top 5 common value:
# date
# 1996-03-17    4
# 1988-03-12    3
# 1993-05-08    3
# 1984-03-14    3
# 1984-03-11    3
# Name: count, dtype: int64

# %% [markdown]
# To present a meaningful graph, we've decided to group the data into 2-year intervals and create a bar plot on this group. This manual binning technique provides a clearer visual representation of the event counts over time, making it easier to identify trends and patterns.

# %%
# Group by 4-year intervals
races['year'] = races['date'].dt.year
races['year_group'] = (races['year'] // 2) * 2  # Round the year to the nearest multiple of 4

# Count occurrences for each 4-year interval
year_counts = races.groupby('year_group').size()

# Create labels for 4-year intervals
year_labels = [f"{year}-{year+1}" for year in year_counts.index]

# Create the bar plot
plt.figure(figsize=(10, 5))
year_counts.plot(kind="bar", color='skyblue')
plt.title('Event Count per 2-Year Interval')
plt.xlabel('2-Year Interval')
plt.ylabel('Count')
plt.xticks(ticks=range(len(year_labels)), labels=year_labels, rotation=45)
plt.grid(axis='y')
plt.tight_layout()
plt.show()
races.drop(columns = ['year_group', 'year'], inplace=True)

# %% [markdown]
# # Data quality

# %% [markdown]
# ### Name

# %% [markdown]
# As we can see by sorting all the unique values of the column name, there are some race names that may refer to the same race event. In fact there are only few differences in those name such as the presence of:
# - accents ['Clásica Ciclista San Sebastian' vs 'Clásica Ciclista San Sebastián]
# - separating characters (- or /) ['Liège - Bastogne - Liège' vs 'Liège-Bastogne-Liège']
# - articles ['La Vuelta ciclista a España' vs 'Vuelta a España]
# - translations ['Ronde van Vlaanderen' vs 'Tour des Flandres]
# Actually this is not a problem for our analysis. The starting part of the _url feature, which is the name of the race event, is correctly formatted for all of these "mismatch" situations.

# %%
unique_names=races['name'].unique()
sorted(unique_names)
# Out:
# ['Amstel Gold Race',
#  'Clasica Ciclista San Sebastian',
#  'Clásica Ciclista San Sebastian',
#  'Clásica Ciclista San Sebastián',
#  'Clásica San Sebastián',
#  'Criterium du Dauphiné',
#  'Criterium du Dauphiné Libére',
#  'Critérium du Dauphiné',
#  'Critérium du Dauphiné Libéré',
#  'Donostia San Sebastian Klasikoa',
#  'Dwars door België / À travers la Belgique',
#  'Dwars door Vlaanderen',
#  'Dwars door Vlaanderen - A travers la Flandre ME',
#  'Dwars door Vlaanderen / A travers la Flandre',
#  'Dwars door Vlaanderen / A travers la Flandre ME',
#  'E3 BinckBank Classic',
#  'E3 Harelbeke',
#  'E3 Prijs Vlaanderen',
#  'E3 Prijs Vlaanderen - Harelbeke',
#  'E3 Saxo Bank Classic',
#  'E3 Saxo Classic',
#  'E3-Prijs Harelbeke',
#  "Giro d'Italia",
#  'Giro di Lombardia',
#  'Gran Camiño',
#  'Grand Prix Cycliste de Montréal',
#  'Grand Prix Cycliste de Quebec',
#  'Grand Prix Cycliste de Québec',
#  'Il Lombardia',
#  'Itzulia Basque Country',
#  'La Flèche Wallonne',
#  'La Vuelta ciclista a España',
#  'Liège - Bastogne - Liège',
#  'Liège-Bastogne-Liège',
#  'Milano-Sanremo',
#  'Monte Paschi Eroica',
#  'Montepaschi Strade Bianche - Eroica Toscana',
#  'O Gran Camiño',
#  'Omloop Het Nieuwsblad ME',
#  'Omloop Het Volk',
#  'Omloop Het Volk ME',
#  'Paris - Nice',
#  'Paris - Roubaix',
#  'Paris-Roubaix',
#  'Record Bank E3 Harelbeke',
#  'Ronde van Vlaanderen - Tour des Flandres ME',
#  'Ronde van Vlaanderen / Tour des Flandres',
#  'Ronde van Vlaanderen / Tour des Flandres ME',
#  'Strade Bianche',
#  'Tirreno-Adriatico',
#  'Tour de France',
#  'Tour de Romandie',
#  'Tour de Suisse',
#  'UAE Tour',
#  'Volta Ciclista a Catalunya',
#  'Volta a Catalunya',
#  'Vuelta Ciclista al País Vasco',
#  'Vuelta a España',
#  'Vuelta al País Vasco',
#  'World Championships - Road Race',
#  'World Championships ME - Road Race']

# %% [markdown]
# **TODO** Vedere correlazione con presenza di ME e maggiore startlist quality

# %% [markdown]
# ### is_gravel, is_tarmac, is_cobbled

# %% [markdown]
# As we can see in the code cell below, the columns _is gravel_ and _is cobbled_ contain only False values. It means that they provide no information because all the records in the dataset have the same value for these attributes (Entropy=0).
# It seems that the 3 attributes representing the race surfaces were obtained by binarizing an original single categorical column.

# %%
races[(races['is_gravel'] == True) | (races['is_cobbled'] == True)].shape[0]
# Out:
# 0

# %% [markdown]
# Regarding the _is tarmac_ feature, most of the records have a true value.

# %%
prob_is_tarmac = races['is_tarmac'].value_counts(normalize=True) 
#normalize=True to get the proportion and not the absolute frequency
print(prob_is_tarmac)
# Out:
# is_tarmac
# 1    0.879568
# 0    0.120432
# Name: proportion, dtype: Float64

# %% [markdown]
# There are also records where all the 3 features have a false value. This may be due to a missing value in the original categorical column before the binarization.

# %%
races[(races['is_gravel'] == False) & (races['is_tarmac'] == False) & (races['is_cobbled'] == False)]
# Out:
#                                   _url  \
# 13    ronde-van-vlaanderen/1980/result
# 15          milano-sanremo/2004/result
# 48       la-fleche-wallone/2015/result
# 52            e3-harelbeke/2002/result
# 69    liege-bastogne-liege/1999/result
# ...                                ...
# 5244        milano-sanremo/1996/result
# 5248      amstel-gold-race/2013/result
# 5268         san-sebastian/2017/result
# 5269             gp-quebec/2010/result
# 5277         paris-roubaix/2000/result
#
#                                           name  points  uci_points  length  \
# 13    Ronde van Vlaanderen / Tour des Flandres     275        <NA>  265000
# 15                              Milano-Sanremo     275        <NA>  294000
# 48                          La Flèche Wallonne     225        <NA>  205500
# 52                          E3-Prijs Harelbeke     125        <NA>  209000
# 69                    Liège - Bastogne - Liège     275        <NA>  264000
# ...                                        ...     ...         ...     ...
# 5244                            Milano-Sanremo     275        <NA>  294000
# 5248                          Amstel Gold Race     225        <NA>  251800
# 5268            Clásica Ciclista San Sebastian     225         400  231000
# 5269             Grand Prix Cycliste de Quebec     225        <NA>  189000
# 5277                           Paris - Roubaix     275        <NA>  273000
#
#       climb_total  profile  startlist_quality  average_temperature  is_tarmac  \
# 13           <NA>     <NA>                602                 <NA>          0
# 15           <NA>     <NA>               1400                 <NA>          0
# 48           3030        3               1112                 <NA>          0
# 52           <NA>        2                400                 <NA>          0
# 69           <NA>     <NA>               1328                 <NA>          0
# ...           ...      ...                ...                  ...        ...
# 5244         <NA>     <NA>               1580                 <NA>          0
# 5248         3500        2               1149                 <NA>          0
# 5268         4156        2                800                 <NA>          0
# 5269         <NA>        3                824                 <NA>          0
# 5277         <NA>        1                808                 <NA>          0
#
#       is_cobbled  is_gravel       date
# 13             0          0 1980-03-30
# 15             0          0 2004-03-20
# 48             0          0 2015-04-22
# 52             0          0 2002-03-30
# 69             0          0 1999-04-18
# ...          ...        ...        ...
# 5244           0          0 1996-03-23
# 5248           0          0 2013-04-14
# 5268           0          0 2017-07-29
# 5269           0          0 2010-09-10
# 5277           0          0 2000-04-10
#
# [636 rows x 13 columns]

# %%
col_entropy = entropy(prob_is_tarmac, base=10)
print(f"The column entropy is: {col_entropy}")
# Out:
# The column entropy is: 0.15972669822251023

# %% [markdown]
# We notice that the only column with both True and False values is '_is_tarmac_'. However, 90.9% of the rows have a True value and only 9.1% have a False value, so this column also provides little information, as we can reasonably assume that every professional cycling competition has a part of the race on asphalt. To support this observation we have also determined the entropy of this column which is very low.

# %% [markdown]
# ### Average Temperature

# %% [markdown]
# This feature has 95% of missing values, so it's very difficult to reconstruct these values in a meaningful way. It could be reasonable to exclude that feature from the further analysis.

# %%
per=(((len(races[races['average_temperature'].isna()]))*100)/len(races))
print(f"Missing values: {per:.2f}%")
# Out:
# Missing values: 96.12%

# %% [markdown]
# ### Points e UCI_points

# %% [markdown]
# The UCI score in cycling is a ranking system used by the Union Cycliste Internationale (UCI) to determine the top cyclists and teams in the world. It is based on a points system where cyclists earn points for their performance in various races throughout the season. The UCI score is used to determine the World Champion, the UCI World Ranking, and the qualification for major cycling events like the Tour de France.
#
# Actually in this dataset the attributes 'uci_points' and 'points' are strictly related to a race event and not, as we would expect, to the placement of a cyclist in a particular race event. The fact that a race has two scores creates a sort of ambiguity.

# %%
races[races['points'].isna()].shape[0]
# Out:
# 4

# %%
races[races['uci_points'].isna()].shape[0]
# Out:
# 3682

# %% [markdown]
# As we can see the feature uci_points has a lot of missing values (>50% of the number of records). In particular all the races held before the 2001 do not have not this information. This may be due the introduction of this scoring system in the early 2000s.

# %%
cutoff_date = pd.to_datetime("2001-1-1")
filtered=races[races['date'] <= cutoff_date]
filtered=filtered.sort_values(by='date', ascending=True)
filtered=filtered[filtered['uci_points'].notna()]
#check if there are missing values before 1/1/2001
filtered.shape[0]==0
# Out:
# True

# %% [markdown]
# Given the fact that, as shown in the correlation analysis section, 'uci_points' and 'points' are highly correlated and 'uci_points' have many missing values, we can decide to drop these feature and maintain only 'points'.

# %% [markdown]
# ### startlist_quality

# %%
races['startlist_quality'].describe()
# Out:
# count    5281.000000
# mean      988.701572
# std       380.450977
# min       115.000000
# 25%       747.000000
# 50%       917.000000
# 75%      1165.000000
# max      2047.000000
# Name: startlist_quality, dtype: float64

# %%
races['startlist_quality'].value_counts()
# Out:
# startlist_quality
# 971     60
# 838     50
# 1872    45
# 1812    45
# 920     43
#         ..
# 1594     1
# 304      1
# 1120     1
# 594      1
# 1149     1
# Name: count, Length: 697, dtype: int64

# %% [markdown]
# check values distribution

# %%
bin_num=int(1+(10/3)*np.log10(len(races['startlist_quality'])))
print(bin_num)
sbn.displot(races, x= "startlist_quality", kind="hist", row_order="desc", bins=bin_num)
# Out:
# 13

# %% [markdown]
# ### Checking whether each _url matches the same startlist_quality value
# We obtain this checking is correct, so it proves that the startlist_quality is a feature linked to the specific race and not to the cyclists.

# %%
# number of unique startlist_quality values for each unique _url
unique_startlists_for_urls = races.groupby('_url')['startlist_quality'].nunique()
inconsistent_urls = unique_startlists_for_urls[unique_startlists_for_urls > 1]
if inconsistent_urls.empty:
    print("For each unique _url there is a specific startlist_quality")
else:
    print("For each unique _url there are different startlist_quality values")
# Out:
# For each unique _url there is a specific startlist_quality

# %% [markdown]
# ### profile
# Checking whether each _url matches the same profile value.
#
# This checking shows that a specific profile correspond to a specific race. The same race doesn't correspond to different profiles.

# %%
# number of unique startlist_quality values for each unique _url
unique_profiles_for_urls = races.groupby('_url')['profile'].nunique()
inconsistent_urls = unique_profiles_for_urls[unique_profiles_for_urls > 1]
if inconsistent_urls.empty:
    print("For each unique _url there is a specific profile")
else:
    print("For each unique _url there are different profile values")
# Out:
# For each unique _url there is a specific profile

# %% [markdown]
# There is no inconsistent information regarding a specific race event. An example of an anomalous situation is the case where two rows referring to the same race event have different values for a race-specific attribute such as length, avg_temperature, profile...

# %%
# count the frequence of each distinct _url
values_count = races['_url'].value_counts()
# if a race has a frequency > 1 then this race may represent an inconsistency between the race's attributes
inconsistent_urls = values_count[values_count > 1]
len(inconsistent_urls)
# Out:
# 0

# %% [markdown]
# ### Length

# %% [markdown]
# As we can see in the notebook section on data distribution, the distribution of the feature _length_ has an anomalous shape. It seems to be a Gaussian distribution, but with a strange peak for very low values of length. This could be due, for example, the use of a different unit of measure to represent the distance (Km vs Metres).
# Perhaps some races have a length expressed in Kilometres rather than Metres, since the maximum for this column is 338000, the mean is 166776.180584 and the minimum is 1000.

# %% [markdown]
# Let's try to identify the race events with a short length value. We initially set a threshold of 10000.

# %%
temp = races[races['length'] <= 10000]
temp['_url'].value_counts()
# Out:
# _url
# volta-a-catalunya/1999/prologue    1
# tour-de-suisse/2007/prologue       1
# paris-nice/2008/prologue           1
# tour-de-suisse/1982/prologue       1
# paris-nice/2000/prologue           1
#                                   ..
# vuelta-a-espana/1987/prologue      1
# tour-de-suisse/1976/prologue       1
# paris-nice/2006/prologue           1
# paris-nice/2013/stage-7            1
# giro-d-italia/2010/stage-1         1
# Name: count, Length: 249, dtype: Int64

# %% [markdown]
# We notice that there are some race events with a length < 10000 and most of them have a suffix of the url matching "prologue" or "stage-1". In fact, by searching information on the project domain, we discovered that the prologue is a short *individual time trial* that takes place at the start of a multi stage race. The prologue has typicalle a maximum length of 8 Km (according to UCI regulations) and it's used to determine the initial time gaps between the riders in the race stages. <br>
#
# Some multistage races have not a prologue but a *stage1* with a short (but >8Km) length or a massive start (not individual).
# [Stage1 vs Prologue](https://www.reddit.com/r/peloton/comments/4nt3yc/prologue_vs_stage_1/)

# %%
#Statistics for prologue races
unique_subset = races[races['_url'].str.contains("prologue")][['_url', 'length']].drop_duplicates(subset=['_url'])
unique_subset.describe()
# Out:
#             length
# count        181.0
# mean   5745.414365
# std    1913.273655
# min         1000.0
# 25%         4100.0
# 50%         5700.0
# 75%         7000.0
# max        10200.0

# %% [markdown]
# # New features
# ## Climb/length ratio
# We decided to introduce the climb/length ratio feature to see if there was still a good/higher correlation with the 'profile' ordinal feature of the race. Note that this is a feature related to the race event itself and not to the cyclist's placement in the race.

# %%
races['climb/length'] = races['climb_total'] / races['length']

# %%
stats_and_distribution(races, 'climb/length', attr_type='numerical')
# Out:
# Description of attribute 'climb/length':
# count      3067.0
# mean     0.014813
# std      0.009059
# min      0.000069
# 25%      0.008803
# 50%      0.013438
# 75%      0.018845
# max      0.103261
# Name: climb/length, dtype: Float64
# Unique values:
# <FloatingArray>
# [0.006796296296296296,  0.02844387755102041,         0.0061015625,
#                  <NA>,  0.01940383618455158, 0.032485106382978725,
#   0.02598076923076923, 0.012971576227390182, 0.028397626112759644,
#   0.02052547770700637,
#  ...
#   0.01946448087431694, 0.017991341991341992, 0.002329479768786127,
#   0.01583221476510067, 0.011720430107526882, 0.006309734513274336,
#  0.019238095238095238, 0.009736486486486487,  0.01378299120234604,
#  0.007142857142857143]
# Length: 3016, dtype: Float64
#
# Null values: 2214 over 5281 records - (41.92%)
#
# Top 5 common value:
# climb/length
# 0.01244     3
# 0.02957     3
# 0.0075      3
# 0.012376    3
# 0.015437    2
# Name: count, dtype: Int64
# Outliers in climb/length: [np.float64(0.0625), np.float64(0.05580808080808081), np.float64(0.03835294117647059), np.float64(0.06345833333333334), np.float64(0.07268518518518519), np.float64(0.05023648648648649), np.float64(0.03691275167785235), np.float64(0.05395833333333333), np.float64(0.05271844660194175), np.float64(0.05446575342465754), np.float64(0.035765217391304345), np.float64(0.0352415210688592), np.float64(0.056), np.float64(0.03459119496855346), np.float64(0.05322916666666667), np.float64(0.036375), np.float64(0.03806363636363636), np.float64(0.03423423423423423), np.float64(0.035515151515151513), np.float64(0.034926470588235295), np.float64(0.03725641025641026), np.float64(0.03976470588235294), np.float64(0.03772350230414746), np.float64(0.044), np.float64(0.05821875), np.float64(0.05023157894736842), np.float64(0.06075313807531381), np.float64(0.046052631578947366), np.float64(0.05101639344262295), np.float64(0.04709090909090909), np.float64(0.03624503311258278), np.float64(0.04594285714285714), np.float64(0.05489583333333333), np.float64(0.037445378151260506), np.float64(0.07126666666666667), np.float64(0.06674074074074074), np.float64(0.03928260869565217), np.float64(0.05514619883040936), np.float64(0.057526881720430106), np.float64(0.03906040268456376), np.float64(0.087), np.float64(0.042339181286549704), np.float64(0.034957627118644065), np.float64(0.036417910447761194), np.float64(0.05092783505154639), np.float64(0.036565371024734984), np.float64(0.03723684210526316), np.float64(0.036036036036036036), np.float64(0.06264925373134328), np.float64(0.0686875), np.float64(0.08403100775193799), np.float64(0.10326086956521739), np.float64(0.0734), np.float64(0.03806060606060606), np.float64(0.055089285714285716), np.float64(0.08929032258064516), np.float64(0.07888888888888888), np.float64(0.06319502074688797), np.float64(0.05574803149606299), np.float64(0.05036923076923077), np.float64(0.038356164383561646)]

# %% [markdown]
# We can observe that the distribution presents a positive skew with a long tail. This means that most of the races have small a climb/length ratio, in particular the climb part of a race event is typically <4%. The boxplot classifies as outliers all the races with a ratio grater than 2.85%. Notice that there is a single race event with an uphill portion of that constitutes 10% of the total distance.

# %%
iqr=(races['climb/length'].quantile(0.75))-(races['climb/length'].quantile(0.25))
print(f"Upper wisker limit: {races['climb/length'].quantile(0.5)+1.5*iqr}")
# Out:
# Upper wisker limit: 0.028501854042755605

# %%
races[races['climb/length']==0.10326086956521739]
# Out:
#                              _url            name  points  uci_points  length  \
# 1144  tour-de-france/1996/stage-9  Tour de France     100        <NA>   46000
#
#       climb_total  profile  startlist_quality  average_temperature  is_tarmac  \
# 1144         4750        5               1872                 <NA>          1
#
#       is_cobbled  is_gravel       date  climb/length
# 1144           0          0 1996-07-08      0.103261

# %%
print(f"Correlation between climb/length and profile: {races['climb/length'].corr(races['profile'], method='kendall')}")
print(f"Correlation between climb and profile: {races['climb_total'].corr(races['profile'], method='kendall')}")
print(f"Correlation between length and profile: {races['length'].corr(races['profile'], method='kendall')}")
# Out:
# Correlation between climb/length and profile: 0.6251513605040532
# Correlation between climb and profile: 0.572520132871134
# Correlation between length and profile: 0.006155688405006674

# %% [markdown]
# As shown by the Kendall scores, which is the best metric for assessing correlation with a rank attribute, using the ratio climb/length has increased the correlation with the ordinal feature 'profile' compared to just looking at the 'climb_total' value.

# %% [markdown]
# # Correlation analysis

# %%
numeric_races = races.select_dtypes(include="number")
numeric_races.corr()
# Out:
#                        points  uci_points    length  climb_total   profile  \
# points               1.000000    0.886923  0.443933     0.148629 -0.130689
# uci_points           0.886923    1.000000  0.308246     0.112018 -0.095515
# length               0.443933    0.308246  1.000000     0.530568  0.070214
# climb_total          0.148629    0.112018  0.530568     1.000000  0.699948
# profile             -0.130689   -0.095515  0.070214     0.699948  1.000000
# startlist_quality    0.150258   -0.027519  0.075864     0.040131 -0.068754
# average_temperature -0.145383   -0.207581 -0.078542    -0.133245  0.008744
# is_tarmac           -0.866794   -0.867166 -0.403898    -0.128214  0.111910
# is_cobbled                NaN         NaN       NaN          NaN       NaN
# is_gravel                 NaN         NaN       NaN          NaN       NaN
# climb/length        -0.058704   -0.057068 -0.181041     0.550005  0.687334
#
#                      startlist_quality  average_temperature  is_tarmac  \
# points                        0.150258            -0.145383  -0.866794
# uci_points                   -0.027519            -0.207581  -0.867166
# length                        0.075864            -0.078542  -0.403898
# climb_total                   0.040131            -0.133245  -0.128214
# profile                      -0.068754             0.008744   0.111910
# startlist_quality             1.000000             0.352969   0.147919
# average_temperature           0.352969             1.000000   0.281753
# is_tarmac                     0.147919             0.281753   1.000000
# is_cobbled                         NaN                  NaN        NaN
# is_gravel                          NaN                  NaN        NaN
# climb/length                  0.012301            -0.089716   0.060291
#
#                      is_cobbled  is_gravel  climb/length
# points                      NaN        NaN     -0.058704
# uci_points                  NaN        NaN     -0.057068
# length                      NaN        NaN     -0.181041
# climb_total                 NaN        NaN      0.550005
# profile                     NaN        NaN      0.687334
# startlist_quality           NaN        NaN      0.012301
# average_temperature         NaN        NaN     -0.089716
# is_tarmac                   NaN        NaN      0.060291
# is_cobbled                  NaN        NaN           NaN
# is_gravel                   NaN        NaN           NaN
# climb/length                NaN        NaN      1.000000

# %%
sbn.scatterplot(data=races, x="points", y="uci_points")
# Out:
# <Axes: xlabel='points', ylabel='uci_points'>

# %% [markdown]
# From this analysis we can see that the 'uci_points' and the 'points' are high correlated, so we can choose to maintain only one of them.

# %% [markdown]
# We can also see that there is a correlation between 'profile' and 'climb', in fact the profile of a race is a ranking of its difficulty and it is influenced by the climbs.

# %% [markdown]
# # Imputation

# %%
def imputationComparison(original_df, imputed_df, column):
    #Two plots in the same row
    fig, axes = plt.subplots(1, 2, figsize=(12, 5))

    sbn.histplot(original_df, x=column, ax=axes[0], kde=True)
    axes[0].set_title(f'Histogram of "{column}" pre-imputation')
    axes[0].set_xlabel(column)
    axes[0].set_ylabel('Frequency')

    sbn.histplot(imputed_df, x=column, ax=axes[1], kde=True)
    axes[1].set_title(f'Histogram of "{column}" after-imputation')
    axes[1].set_xlabel(column)
    axes[1].set_ylabel('Frequency')

    plt.tight_layout()
    plt.show()
    plt.close()

# %% [markdown]
# ## Points

# %%
races[races['points'].isna()]
# Out:
#                               _url             name  points  uci_points  \
# 1423  vuelta-a-espana/1994/stage-5  Vuelta a España    <NA>        <NA>
# 4167  tour-de-france/1986/stage-19   Tour de France    <NA>        <NA>
# 4661  tour-de-france/1988/prologue   Tour de France    <NA>        <NA>
# 5035  tour-de-france/2019/stage-19   Tour de France    <NA>        <NA>
#
#       length  climb_total  profile  startlist_quality  average_temperature  \
# 1423  166900         1547     <NA>                791                 <NA>
# 4167  179500         3000        4               1872                 <NA>
# 4661    1000           44        1               1941                 <NA>
# 5035   89000         2995        5               1699                 <NA>
#
#       is_tarmac  is_cobbled  is_gravel       date  climb/length
# 1423          1           0          0 1994-04-29      0.009269
# 4167          1           0          0 1986-07-23      0.016713
# 4661          1           0          0 1988-07-03         0.044
# 5035          1           0          0 2019-07-26      0.033652

# %% [markdown]
# As we can see there are only 4 race events for which we have not the point reference. Let's see again which 'points' are typically assigned to a race; we expect them to be to assume values in a defined set/range.

# %%
points_set=np.sort(races['points'].unique())
points_set
# Out:
# array([ 18.,  20.,  30.,  35.,  50.,  70.,  75.,  80., 100., 125., 150.,
#        225., 275., 350.,  nan])

# %%
tdf_no_points=races[races['_url'].str.contains(r'tour-de-france/\d{4}/stage-19', regex=True)].sort_values(by="_url")
tdf_no_points
# Out:
#                               _url            name  points  uci_points  \
# 230   tour-de-france/1978/stage-19  Tour de France     100        <NA>
# 334   tour-de-france/1979/stage-19  Tour de France     100        <NA>
# 1927  tour-de-france/1980/stage-19  Tour de France     100        <NA>
# 971   tour-de-france/1981/stage-19  Tour de France     100        <NA>
# 5055  tour-de-france/1982/stage-19  Tour de France     100        <NA>
# 1310  tour-de-france/1983/stage-19  Tour de France     100        <NA>
# 913   tour-de-france/1984/stage-19  Tour de France     100        <NA>
# 3530  tour-de-france/1985/stage-19  Tour de France     100        <NA>
# 4167  tour-de-france/1986/stage-19  Tour de France    <NA>        <NA>
# 1770  tour-de-france/1987/stage-19  Tour de France     100        <NA>
# 3353  tour-de-france/1988/stage-19  Tour de France     100        <NA>
# 449   tour-de-france/1989/stage-19  Tour de France     100        <NA>
# 406   tour-de-france/1990/stage-19  Tour de France     100        <NA>
# 5180  tour-de-france/1991/stage-19  Tour de France     100        <NA>
# 1461  tour-de-france/1992/stage-19  Tour de France     100        <NA>
# 3739  tour-de-france/1993/stage-19  Tour de France     100        <NA>
# 4702  tour-de-france/1994/stage-19  Tour de France     100        <NA>
# 830   tour-de-france/1995/stage-19  Tour de France     100        <NA>
# 4723  tour-de-france/1996/stage-19  Tour de France     100        <NA>
# 707   tour-de-france/1997/stage-19  Tour de France     100        <NA>
# 135   tour-de-france/1999/stage-19  Tour de France      70        <NA>
# 3163  tour-de-france/2000/stage-19  Tour de France      70        <NA>
# 3245  tour-de-france/2001/stage-19  Tour de France     100        <NA>
# 3086  tour-de-france/2002/stage-19  Tour de France      70        <NA>
# 1520  tour-de-france/2003/stage-19  Tour de France     100        <NA>
# 2116  tour-de-france/2004/stage-19  Tour de France      70        <NA>
# 4813  tour-de-france/2005/stage-19  Tour de France     100        <NA>
# 2489  tour-de-france/2007/stage-19  Tour de France     100        <NA>
# 2615  tour-de-france/2008/stage-19  Tour de France     100        <NA>
# 4676  tour-de-france/2009/stage-19  Tour de France     100        <NA>
# 4046  tour-de-france/2010/stage-19  Tour de France     100          20
# 2086  tour-de-france/2011/stage-19  Tour de France     100          20
# 3954  tour-de-france/2012/stage-19  Tour de France     100          20
# 331   tour-de-france/2013/stage-19  Tour de France     100          20
# 2570  tour-de-france/2014/stage-19  Tour de France     100          20
# 4064  tour-de-france/2015/stage-19  Tour de France     100          20
# 336   tour-de-france/2016/stage-19  Tour de France     100         120
# 3095  tour-de-france/2017/stage-19  Tour de France     100         120
# 2254  tour-de-france/2018/stage-19  Tour de France     100         120
# 5035  tour-de-france/2019/stage-19  Tour de France    <NA>        <NA>
# 2004  tour-de-france/2021/stage-19  Tour de France     100         120
# 786   tour-de-france/2022/stage-19  Tour de France     100         120
# 2727  tour-de-france/2023/stage-19  Tour de France     100         210
#
#       length  climb_total  profile  startlist_quality  average_temperature  \
# 230   182000         2000        2               1241                 <NA>
# 334   162000         1568        2               1381                 <NA>
# 1927  136500         2439        4               1224                 <NA>
# 971   117500         1996        2               1362                 <NA>
# 5055   48000          508        2               1492                 <NA>
# 1310   15000         1069        5               1269                 <NA>
# 913   186000         5500        4               1632                 <NA>
# 3530  200000         1637        1               1470                 <NA>
# 4167  179500         3000        4               1872                 <NA>
# 1770  185000         4842        4               1812                 <NA>
# 3353  188000         4079        5               1941                 <NA>
# 449   125000         2500        4               1849                 <NA>
# 406   182500         1114        1               1959                 <NA>
# 5180  177000         3000        2               1933                 <NA>
# 1461   64000          624        2               2047                 <NA>
# 3739   48000          608        1               1804                 <NA>
# 4702   47500         2386        5               1731                 <NA>
# 830    46000         1097        1               1871                 <NA>
# 4723  226500         1754        1               1872                 <NA>
# 707   172000         1776        1               1994                 <NA>
# 135    57000          543        1               1255                 <NA>
# 3163   58500          235        1               1437                 <NA>
# 3245  149500         1022        1               1496                 <NA>
# 3086   50000          857        1               1489                 <NA>
# 1520   49000          395        1               1688                 <NA>
# 2116   55000         1042        3               1555                 <NA>
# 4813  154000         2344        3               1535                 <NA>
# 2489   55500          480        1               1612                 <NA>
# 2615  165500         1814        1               1520                 <NA>
# 4676  178000         1891        4               1557                 <NA>
# 4046   52000          167        1               1685                 <NA>
# 2086  109500         3571        5               1713                 <NA>
# 3954   53500          249        1               1703                 <NA>
# 331   204500         5567        4               1690                 <NA>
# 2570  208500         1659        1               1612                 <NA>
# 4064  138000         4545        5               1812                 <NA>
# 336   146000         4436        5               1758                 <NA>
# 3095  222500         2613        1               1791                 <NA>
# 2254  200500         5046        4               1689                 <NA>
# 5035   89000         2995        5               1699                 <NA>
# 2004  207000         1181        2               1646                 <NA>
# 786   188300         1316        3               1551                   30
# 2727  172800         1934        2               1584                   21
#
#       is_tarmac  is_cobbled  is_gravel       date  climb/length
# 230           1           0          0 1978-07-20      0.010989
# 334           1           0          0 1979-07-17      0.009679
# 1927          1           0          0 1980-07-17      0.017868
# 971           1           0          0 1981-07-16      0.016987
# 5055          1           0          0 1982-07-23      0.010583
# 1310          1           0          0 1983-07-21      0.071267
# 913           1           0          0 1984-07-18       0.02957
# 3530          1           0          0 1985-07-18      0.008185
# 4167          1           0          0 1986-07-23      0.016713
# 1770          1           0          0 1987-07-20      0.026173
# 3353          1           0          0 1988-07-21      0.021697
# 449           1           0          0 1989-07-21          0.02
# 406           1           0          0 1990-07-20      0.006104
# 5180          1           0          0 1991-07-25      0.016949
# 1461          1           0          0 1992-07-24       0.00975
# 3739          1           0          0 1993-07-24      0.012667
# 4702          1           0          0 1994-07-22      0.050232
# 830           1           0          0 1995-07-22      0.023848
# 4723          1           0          0 1996-07-19      0.007744
# 707           1           0          0 1997-07-25      0.010326
# 135           1           0          0 1999-07-24      0.009526
# 3163          1           0          0 2000-07-21      0.004017
# 3245          1           0          0 2001-07-28      0.006836
# 3086          1           0          0 2002-07-27       0.01714
# 1520          1           0          0 2003-07-26      0.008061
# 2116          1           0          0 2004-07-24      0.018945
# 4813          1           0          0 2005-07-22      0.015221
# 2489          1           0          0 2007-07-28      0.008649
# 2615          1           0          0 2008-07-25      0.010961
# 4676          1           0          0 2009-07-24      0.010624
# 4046          1           0          0 2010-07-24      0.003212
# 2086          1           0          0 2011-07-22      0.032612
# 3954          1           0          0 2012-07-21      0.004654
# 331           1           0          0 2013-07-19      0.027222
# 2570          1           0          0 2014-07-25      0.007957
# 4064          1           0          0 2015-07-24      0.032935
# 336           1           0          0 2016-07-22      0.030384
# 3095          1           0          0 2017-07-21      0.011744
# 2254          1           0          0 2018-07-27      0.025167
# 5035          1           0          0 2019-07-26      0.033652
# 2004          1           0          0 2021-07-16      0.005705
# 786           1           0          0 2022-07-22      0.006989
# 2727          1           0          0 2023-07-21      0.011192

# %%
tour_de_france_df = races[races['_url'].str.startswith('tour-de-france')]
tour_de_france_df['points'].value_counts(normalize=True)
# Out:
# points
# 100    0.975771
# 70     0.023128
# 50     0.001101
# Name: proportion, dtype: Float64

# %% [markdown]
# We can observe that 97% of the stages of the "Tour de France" have a score of 100. Since the scores are "drawn" from a specific set, as already told before, it's reasonable to assign the score 100 to the 3 stages of the "Tour de France" with a NaN reference.

# %%
rows_to_fill = races[(races['_url'].str.startswith('tour-de-france'))&(races['points'].isna())]
rows_to_fill
# Out:
#                               _url            name  points  uci_points  \
# 4167  tour-de-france/1986/stage-19  Tour de France    <NA>        <NA>
# 4661  tour-de-france/1988/prologue  Tour de France    <NA>        <NA>
# 5035  tour-de-france/2019/stage-19  Tour de France    <NA>        <NA>
#
#       length  climb_total  profile  startlist_quality  average_temperature  \
# 4167  179500         3000        4               1872                 <NA>
# 4661    1000           44        1               1941                 <NA>
# 5035   89000         2995        5               1699                 <NA>
#
#       is_tarmac  is_cobbled  is_gravel       date  climb/length
# 4167          1           0          0 1986-07-23      0.016713
# 4661          1           0          0 1988-07-03         0.044
# 5035          1           0          0 2019-07-26      0.033652

# %%
rows_to_fill.loc[:, 'points'] = rows_to_fill['points'].fillna(100)
races.update(rows_to_fill) #update the dataframe which still have NaNs

# %%
races[races['points'].isna()]
# Out:
#                               _url             name  points  uci_points  \
# 1423  vuelta-a-espana/1994/stage-5  Vuelta a España    <NA>        <NA>
#
#       length  climb_total  profile  startlist_quality  average_temperature  \
# 1423  166900         1547     <NA>                791                 <NA>
#
#       is_tarmac  is_cobbled  is_gravel       date  climb/length
# 1423          1           0          0 1994-04-29      0.009269

# %%
vae_no_points=races[races['_url'].str.startswith('vuelta-a-espana')]
vae_no_points['points'].value_counts(normalize=True)
# Out:
# points
# 80    0.996641
# 50    0.003359
# Name: proportion, dtype: Float64

# %% [markdown]
# Since 99% of the race events related to '_vuelta-a-espana_' have a score of 80, we decide to impute the only stage with a NaN using this value.

# %%
rows_to_fill = races[(races['_url'].str.startswith('vuelta-a-espana'))&(races['points'].isna())]
rows_to_fill.loc[:, 'points'] = rows_to_fill['points'].fillna(80)
races.update(rows_to_fill) #update the dataframe which still have NaNs

# %%
races[races['points'].isna()]
# Out:
# Empty DataFrame
# Columns: [_url, name, points, uci_points, length, climb_total, profile, startlist_quality, average_temperature, is_tarmac, is_cobbled, is_gravel, date, climb/length]
# Index: []

# %% [markdown]
# ## Climb_total

# %%
races.columns
# Out:
# Index(['_url', 'name', 'points', 'uci_points', 'length', 'climb_total',
#        'profile', 'startlist_quality', 'average_temperature', 'is_tarmac',
#        'is_cobbled', 'is_gravel', 'date', 'climb/length'],
#       dtype='object')

# %% [markdown]
# Read placements dataset

# %%
placements = pd.read_csv('../dataset/preprocessedPlacements.csv', sep=",")

# %% [markdown]
# We derive two new features _mean\_delta_ and _std\_delta_, by calculating the mean and standard deviation of the _delta_ column for each _\_url_ group in placements and assigning these values to each row within the respective group

# %%
placements['mean_delta'] = placements.groupby('_url')['delta'].transform('mean')
placements['std_delta'] = placements.groupby('_url')['delta'].transform('std')

# %% [markdown]
# Then we want to add these features to the races dataframe, as they are general fields related to the race rather than individual placements.
#
# Before performing the inner join, we check the consistency of _urls.

# %%
if races['_url'].isin(placements['_url']).all():
    races = races.merge(
        placements.groupby('_url')['delta'].agg(mean_delta='mean', std_delta='std').reset_index(),
        on='_url', how='inner'
    )
    print("Inner join done: each rows in races has a match in placements")
else:
    print("Inner join issue: some rows in races doesn't match in placements")
# Out:
# Inner join done: each rows in races has a match in placements

# %%
races_pre_imputation=races.copy()
races.columns
# Out:
# Index(['_url', 'name', 'points', 'uci_points', 'length', 'climb_total',
#        'profile', 'startlist_quality', 'average_temperature', 'is_tarmac',
#        'is_cobbled', 'is_gravel', 'date', 'climb/length', 'mean_delta',
#        'std_delta'],
#       dtype='object')

# %%
races
# Out:
#                                  _url                        name  points  \
# 0         tour-de-france/1978/stage-6              Tour de France     100
# 1       vuelta-a-espana/2016/stage-14             Vuelta a España      80
# 2        tour-de-france/2019/stage-21              Tour de France     100
# 3     volta-a-catalunya/1999/prologue  Volta Ciclista a Catalunya      50
# 4         tour-de-france/2022/stage-9              Tour de France     100
# ...                               ...                         ...     ...
# 5276       giro-d-italia/2017/stage-3               Giro d'Italia      80
# 5277        paris-roubaix/2000/result             Paris - Roubaix     275
# 5278          paris-nice/1976/stage-2                Paris - Nice      50
# 5279   volta-a-catalunya/2016/stage-7  Volta Ciclista a Catalunya      50
# 5280       giro-d-italia/2010/stage-1               Giro d'Italia      80
#
#       uci_points  length  climb_total  profile  startlist_quality  \
# 0           <NA>  162000         1101        1               1241
# 1            100  196000         5575        5                821
# 2            120  128000          781        1               1699
# 3           <NA>    8100         <NA>     <NA>                804
# 4            120  192900         3743        3               1551
# ...          ...     ...          ...      ...                ...
# 5276         100  148000         1441        1                881
# 5277        <NA>  273000         <NA>        1                808
# 5278        <NA>  185000         <NA>     <NA>                779
# 5279          50  136400         1880        2               1045
# 5280          16    8400           60        1                878
#
#       average_temperature  is_tarmac  is_cobbled  is_gravel       date  \
# 0                    <NA>          1           0          0 1978-07-05
# 1                    <NA>          1           0          0 2016-09-03
# 2                    <NA>          1           0          0 2019-07-28
# 3                    <NA>          1           0          0 1999-06-17
# 4                      24          1           0          0 2022-07-10
# ...                   ...        ...         ...        ...        ...
# 5276                 <NA>          1           0          0 2017-05-07
# 5277                 <NA>          0           0          0 2000-04-10
# 5278                 <NA>          1           0          0 1976-03-09
# 5279                 <NA>          1           0          0 2016-03-27
# 5280                 <NA>          1           0          0 2010-05-08
#
#       climb/length   mean_delta   std_delta
# 0         0.006796    26.075472    6.847590
# 1         0.028444  1508.787879  873.835670
# 2         0.006102    39.612903   44.079531
# 3             <NA>    57.436975   27.154498
# 4         0.019404  1140.963415  675.354230
# ...            ...          ...         ...
# 5276      0.009736   134.835897  120.702086
# 5277          <NA>   389.666667  327.665558
# 5278          <NA>     0.000000    0.000000
# 5279      0.013783   221.936508  176.293335
# 5280      0.007143    40.903553   18.663941
#
# [5281 rows x 16 columns]

# %%
races.isna().sum()
# Out:
# _url                      0
# name                      0
# points                    0
# uci_points             3682
# length                    0
# climb_total            2214
# profile                2408
# startlist_quality         0
# average_temperature    5076
# is_tarmac                 0
# is_cobbled                0
# is_gravel                 0
# date                      0
# climb/length           2214
# mean_delta                0
# std_delta                 6
# dtype: int64

# %%
races.shape[0]
# Out:
# 5281

# %%
no_climb_total_urls=races[races['climb_total'].isna()]['_url'].tolist()
len(no_climb_total_urls)
# Out:
# 2214

# %%
races_pre_imputation=races.copy()

# %% [markdown]
# ### Standardization
# We standardize selected numeric features in the _races\_date_ dataframe. We do not consider columns with many NaNs, high correlation, or non-numeric values. The selected features are scaled to have a mean of 0 and a standard deviation of 1.

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
#no 'uci_points' because there are a lot of NaNs and it is highly correlated to points
#no 'average_temperature' because 96% of the values are NaNs
#no 'profile' because it's an ordinal feature
#no 'climb/lenght' because it's an artificial column that is not used here
numeric_columns=['points', 'length', 'climb_total', 'startlist_quality', 'mean_delta', 'std_delta']
numeric_races=races[numeric_columns]
scaler.fit(numeric_races)
X = scaler.transform(numeric_races)

# %%
X
# Out:
# array([[ 0.1715365 , -0.05429348, -0.91427639,  0.66321901, -0.45146243,
#         -0.435724  ],
#        [-0.15426841,  0.44656511,  2.29481713, -0.44083854,  1.63151802,
#          1.25213331],
#        [ 0.1715365 , -0.55515206, -1.14380476,  1.86716747, -0.43244445,
#         -0.36324064],
#        ...,
#        [-0.64297576,  0.28452262,         nan, -0.55124429, -0.48809442,
#         -0.44905492],
#        [-0.64297576, -0.43141053, -0.35551827,  0.14799215, -0.17630812,
#         -0.10584606],
#        [-0.15426841, -2.31699579, -1.66096087, -0.29100216, -0.43063128,
#         -0.41271986]])

# %% [markdown]
# Creation of a dataframe from those standardized data

# %%
standardized_races = pd.DataFrame(X, columns=numeric_columns)
standardized_races
# Out:
#         points    length  climb_total  startlist_quality  mean_delta  \
# 0     0.171536 -0.054293    -0.914276           0.663219   -0.451462
# 1    -0.154268  0.446565     2.294817          -0.440839    1.631518
# 2     0.171536 -0.555152    -1.143805           1.867167   -0.432444
# 3    -0.642976 -2.321415          NaN          -0.485527   -0.407404
# 4     0.171536  0.400899     0.980767           1.478119    1.114782
# ...        ...       ...          ...                ...         ...
# 5276 -0.154268 -0.260529    -0.670402          -0.283116   -0.298671
# 5277  3.022329  1.580862          NaN          -0.475012    0.059327
# 5278 -0.642976  0.284523          NaN          -0.551244   -0.488094
# 5279 -0.642976 -0.431411    -0.355518           0.147992   -0.176308
# 5280 -0.154268 -2.316996    -1.660961          -0.291002   -0.430631
#
#       std_delta
# 0     -0.435724
# 1      1.252133
# 2     -0.363241
# 3     -0.396190
# 4      0.865729
# ...         ...
# 5276  -0.214071
# 5277   0.188846
# 5278  -0.449055
# 5279  -0.105846
# 5280  -0.412720
#
# [5281 rows x 6 columns]

# %%
def distributionComparison_for_KNN(original_df, imputed_df, column, k):
    #Two plots in the same row
    fig, axes = plt.subplots(1, 2, figsize=(10, 4))

    sbn.histplot(original_df, x=column, ax=axes[0], kde=True)
    axes[0].set_title(f'Histogram of "{column}" pre-imputation')
    axes[0].set_xlabel(column)
    axes[0].set_ylabel('Frequency')

    sbn.histplot(imputed_df, x=column, ax=axes[1], kde=True)
    axes[1].set_title(f'Histogram of "{column}" after-imputation with k={k}')
    axes[1].set_xlabel(column)
    axes[1].set_ylabel('Frequency')

    plt.tight_layout()
    plt.show()

# %% [markdown]
# ### KNN imputation
# We evaluate KNN imputation for missing values by testing different values of k (from 1 to 6). For each k, the missing data is imputed using KNN with distance-based weighting. The distribution of the imputed data for the _climb\_total_ column is compared with the pre-imputation distribution.

# %%
from sklearn.impute import KNNImputer

#range of k to evaluate imputation 
k_values = range(1, 7)  

for idx, k in enumerate(k_values, start=1):
    imputer = KNNImputer(n_neighbors=k, weights="distance")
    imputed_data = imputer.fit_transform(standardized_races)
    
    #Get back to the de-normalized representation
    df_imputed=pd.DataFrame(scaler.inverse_transform(imputed_data), columns=numeric_columns)

    races['climb_total']=df_imputed['climb_total']
    distributionComparison_for_KNN(races_pre_imputation, races, 'climb_total', k)

# %% [markdown]
# Based on the distributions obtained after imputation, the one that deviates the least from the original distribution is obtained with k=4, so we choose this value for imputation.

# %%
races.to_csv('../dataset/preprocessedRaces.csv', index=False)
